# %%
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from nltk.tokenize import TweetTokenizer
from collections import defaultdict

# %%
dataset_path = './data/sentiment_analysis.csv'
df = pd.read_csv(dataset_path,
                 index_col='id')

# %%
df
# Out:
#       label                                              tweet
# id
# 1         0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2         0  Finally a transparant silicon case ^^ Thanks t...
# 3         0  We love this! Would you go? #talk #makememorie...
# 4         0  I'm wired I know I'm George I was made that wa...
# 5         1  What amazing service! Apple won't even talk to...
# ...     ...                                                ...
# 7916      0  Live out loud #lol #liveoutloud #selfie #smile...
# 7917      0  We would like to wish you an amazing day! Make...
# 7918      0  Helping my lovely 90 year old neighbor with he...
# 7919      0  Finally got my #smart #pocket #wifi stay conne...
# 7920      0  Apple Barcelona!!! #Apple #Store #BCN #Barcelo...
#
# [7920 rows x 2 columns]

# %%
def text_normalize(text):
  text = re.sub(r'^RT[\s]+', '', text)
  text = re.sub(r'http?:\/\/.*[\r\n]*', '', text)
  text = re.sub(r'#', '', text)
  text = re.sub(r'[^\w\s]', '', text)

  tokenizer = TweetTokenizer(
      preserve_case=False,
      strip_handles=True,
      reduce_len=True
  )
  text_tokens = tokenizer.tokenize(text)

  return text_tokens

# %%
def get_freqs(df):
  freqs = defaultdict(lambda: 0)
  for idx, row in df.iterrows():
    tweet = row['tweet']
    label = row['label']

    tokens = text_normalize(tweet)
    for token in tokens:
      pair = (token, label)
      freqs[pair] += 1

  return freqs

# %%
def get_feature(text, freqs):
  tokens = text_normalize(text)

  X = np.zeros(3)
  X[0] = 1

  for token in tokens:
    X[1] += freqs[(token, 0)]
    X[2] += freqs[(token, 1)]

  return X

# %%
X = []
y = []

freqs = get_freqs(df)
for idx, row in df.iterrows():
  tweet = row['tweet']
  label = row['label']

  X_i = get_feature(tweet, freqs)

  X.append(X_i)
  y.append(label)

X = np.array(X)
y = np.array(y)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def compute_loss(y_hat, y):
    y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)
    return (-y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)).mean()

def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmoid(dot_product)
    return y_hat

def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

def update_theta(theta, gradient, lr):
    return theta - lr * gradient

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    return acc

# %%
lr = 0.01
epochs = 200
batch_size = 128

np.random.seed(random_state)
theta = np.random.uniform(size=X_train.shape[1])

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []
for epoch in range(epochs):
  train_batch_losses = []
  train_batch_accs = []
  val_batch_losses = []
  val_batch_accs = []
  for batch in range(0, X_train.shape[0], batch_size):
    X_i = X_train[batch:batch + batch_size]
    y_i = y_train[batch:batch + batch_size]

    y_hat = predict(X_i, theta)
    loss = compute_loss(y_i, y_hat)
    gradient = compute_gradient(X_i, y_i, y_hat)
    theta = update_theta(theta, gradient, lr)
    acc = compute_accuracy(X_train, y_train, theta)

    train_batch_losses.append(loss)
    train_batch_accs.append(acc)

    y_val_hat = predict(X_val, theta)
    val_loss = compute_loss(y_val, y_val_hat)
    val_acc = compute_accuracy(X_val, y_val, theta)

    val_batch_losses.append(val_loss)
    val_batch_accs.append(val_acc)

  train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
  val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
  train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
  val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

  train_accs.append(train_batch_acc)
  train_losses.append(train_batch_loss)
  val_accs.append(val_batch_acc)
  val_losses.append(val_batch_loss)

  print(f"\nEPOCH {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}")
# Out:
# EPOCH 1:	Training loss: 7.781	Validation loss: 7.755
#
# EPOCH 2:	Training loss: 7.451	Validation loss: 7.427
#
# EPOCH 3:	Training loss: 7.161	Validation loss: 7.138
#
# EPOCH 4:	Training loss: 6.905	Validation loss: 6.883
#
# EPOCH 5:	Training loss: 6.681	Validation loss: 6.660
#
# EPOCH 6:	Training loss: 6.484	Validation loss: 6.464
#
# EPOCH 7:	Training loss: 6.310	Validation loss: 6.291
#
# EPOCH 8:	Training loss: 6.157	Validation loss: 6.138
#
# EPOCH 9:	Training loss: 6.020	Validation loss: 6.002
#
# EPOCH 10:	Training loss: 5.898	Validation loss: 5.881
#
# EPOCH 11:	Training loss: 5.789	Validation loss: 5.772
#
# EPOCH 12:	Training loss: 5.691	Validation loss: 5.674
#
# EPOCH 13:	Training loss: 5.603	Validation loss: 5.586
#
# EPOCH 14:	Training loss: 5.523	Validation loss: 5.506
#
# EPOCH 15:	Training loss: 5.450	Validation loss: 5.434
#
# EPOCH 16:	Training loss: 5.383	Validation loss: 5.367
#
# EPOCH 17:	Training loss: 5.322	Validation loss: 5.306
#
# EPOCH 18:	Training loss: 5.266	Validation loss: 5.250
#
# EPOCH 19:	Training loss: 5.214	Validation loss: 5.199
#
# EPOCH 20:	Training loss: 5.167	Validation loss: 5.151
#
# EPOCH 21:	Training loss: 5.122	Validation loss: 5.107
#
# EPOCH 22:	Training loss: 5.081	Validation loss: 5.066
#
# EPOCH 23:	Training loss: 5.043	Validation loss: 5.027
#
# EPOCH 24:	Training loss: 5.007	Validation loss: 4.991
#
# EPOCH 25:	Training loss: 4.973	Validation loss: 4.958
#
# EPOCH 26:	Training loss: 4.942	Validation loss: 4.926
#
# EPOCH 27:	Training loss: 4.912	Validation loss: 4.896
#
# EPOCH 28:	Training loss: 4.884	Validation loss: 4.868
#
# EPOCH 29:	Training loss: 4.857	Validation loss: 4.842
#
# EPOCH 30:	Training loss: 4.832	Validation loss: 4.817
#
# EPOCH 31:	Training loss: 4.809	Validation loss: 4.793
#
# EPOCH 32:	Training loss: 4.786	Validation loss: 4.771
#
# EPOCH 33:	Training loss: 4.765	Validation loss: 4.749
#
# EPOCH 34:	Training loss: 4.745	Validation loss: 4.729
#
# EPOCH 35:	Training loss: 4.725	Validation loss: 4.710
#
# EPOCH 36:	Training loss: 4.707	Validation loss: 4.691
#
# EPOCH 37:	Training loss: 4.689	Validation loss: 4.673
#
# EPOCH 38:	Training loss: 4.672	Validation loss: 4.656
#
# EPOCH 39:	Training loss: 4.656	Validation loss: 4.640
#
# EPOCH 40:	Training loss: 4.641	Validation loss: 4.625
#
# EPOCH 41:	Training loss: 4.626	Validation loss: 4.610
#
# EPOCH 42:	Training loss: 4.611	Validation loss: 4.595
#
# EPOCH 43:	Training loss: 4.598	Validation loss: 4.582
#
# EPOCH 44:	Training loss: 4.584	Validation loss: 4.568
#
# EPOCH 45:	Training loss: 4.572	Validation loss: 4.555
#
# EPOCH 46:	Training loss: 4.559	Validation loss: 4.543
#
# EPOCH 47:	Training loss: 4.547	Validation loss: 4.531
#
# EPOCH 48:	Training loss: 4.536	Validation loss: 4.520
#
# EPOCH 49:	Training loss: 4.525	Validation loss: 4.508
#
# EPOCH 50:	Training loss: 4.514	Validation loss: 4.498
#
# EPOCH 51:	Training loss: 4.504	Validation loss: 4.487
#
# EPOCH 52:	Training loss: 4.494	Validation loss: 4.477
#
# EPOCH 53:	Training loss: 4.484	Validation loss: 4.467
#
# EPOCH 54:	Training loss: 4.474	Validation loss: 4.458
#
# EPOCH 55:	Training loss: 4.465	Validation loss: 4.448
#
# EPOCH 56:	Training loss: 4.456	Validation loss: 4.439
#
# EPOCH 57:	Training loss: 4.447	Validation loss: 4.431
#
# EPOCH 58:	Training loss: 4.439	Validation loss: 4.422
#
# EPOCH 59:	Training loss: 4.431	Validation loss: 4.414
#
# EPOCH 60:	Training loss: 4.423	Validation loss: 4.406
#
# EPOCH 61:	Training loss: 4.415	Validation loss: 4.398
#
# EPOCH 62:	Training loss: 4.407	Validation loss: 4.390
#
# EPOCH 63:	Training loss: 4.400	Validation loss: 4.383
#
# EPOCH 64:	Training loss: 4.393	Validation loss: 4.375
#
# EPOCH 65:	Training loss: 4.386	Validation loss: 4.368
#
# EPOCH 66:	Training loss: 4.379	Validation loss: 4.361
#
# EPOCH 67:	Training loss: 4.372	Validation loss: 4.355
#
# EPOCH 68:	Training loss: 4.365	Validation loss: 4.348
#
# EPOCH 69:	Training loss: 4.359	Validation loss: 4.341
#
# EPOCH 70:	Training loss: 4.353	Validation loss: 4.335
#
# EPOCH 71:	Training loss: 4.346	Validation loss: 4.329
#
# EPOCH 72:	Training loss: 4.340	Validation loss: 4.323
#
# EPOCH 73:	Training loss: 4.334	Validation loss: 4.317
#
# EPOCH 74:	Training loss: 4.329	Validation loss: 4.311
#
# EPOCH 75:	Training loss: 4.323	Validation loss: 4.305
#
# EPOCH 76:	Training loss: 4.317	Validation loss: 4.300
#
# EPOCH 77:	Training loss: 4.312	Validation loss: 4.294
#
# EPOCH 78:	Training loss: 4.307	Validation loss: 4.289
#
# EPOCH 79:	Training loss: 4.301	Validation loss: 4.283
#
# EPOCH 80:	Training loss: 4.296	Validation loss: 4.278
#
# EPOCH 81:	Training loss: 4.291	Validation loss: 4.273
#
# EPOCH 82:	Training loss: 4.286	Validation loss: 4.268
#
# EPOCH 83:	Training loss: 4.281	Validation loss: 4.263
#
# EPOCH 84:	Training loss: 4.276	Validation loss: 4.258
#
# EPOCH 85:	Training loss: 4.272	Validation loss: 4.254
#
# EPOCH 86:	Training loss: 4.267	Validation loss: 4.249
#
# EPOCH 87:	Training loss: 4.262	Validation loss: 4.244
#
# EPOCH 88:	Training loss: 4.258	Validation loss: 4.240
#
# EPOCH 89:	Training loss: 4.254	Validation loss: 4.235
#
# EPOCH 90:	Training loss: 4.249	Validation loss: 4.231
#
# EPOCH 91:	Training loss: 4.245	Validation loss: 4.227
#
# EPOCH 92:	Training loss: 4.241	Validation loss: 4.222
#
# EPOCH 93:	Training loss: 4.237	Validation loss: 4.218
#
# EPOCH 94:	Training loss: 4.233	Validation loss: 4.214
#
# EPOCH 95:	Training loss: 4.229	Validation loss: 4.210
#
# EPOCH 96:	Training loss: 4.225	Validation loss: 4.206
#
# EPOCH 97:	Training loss: 4.221	Validation loss: 4.202
#
# EPOCH 98:	Training loss: 4.217	Validation loss: 4.198
#
# EPOCH 99:	Training loss: 4.213	Validation loss: 4.195
#
# EPOCH 100:	Training loss: 4.210	Validation loss: 4.191
#
# EPOCH 101:	Training loss: 4.206	Validation loss: 4.187
#
# EPOCH 102:	Training loss: 4.202	Validation loss: 4.183
#
# EPOCH 103:	Training loss: 4.199	Validation loss: 4.180
#
# EPOCH 104:	Training loss: 4.195	Validation loss: 4.176
#
# EPOCH 105:	Training loss: 4.192	Validation loss: 4.173
#
# EPOCH 106:	Training loss: 4.188	Validation loss: 4.169
#
# EPOCH 107:	Training loss: 4.185	Validation loss: 4.166
#
# EPOCH 108:	Training loss: 4.182	Validation loss: 4.163
#
# EPOCH 109:	Training loss: 4.178	Validation loss: 4.159
#
# EPOCH 110:	Training loss: 4.175	Validation loss: 4.156
#
# EPOCH 111:	Training loss: 4.172	Validation loss: 4.153
#
# EPOCH 112:	Training loss: 4.169	Validation loss: 4.150
#
# EPOCH 113:	Training loss: 4.166	Validation loss: 4.147
#
# EPOCH 114:	Training loss: 4.163	Validation loss: 4.143
#
# EPOCH 115:	Training loss: 4.160	Validation loss: 4.140
#
# EPOCH 116:	Training loss: 4.157	Validation loss: 4.137
#
# EPOCH 117:	Training loss: 4.154	Validation loss: 4.134
#
# EPOCH 118:	Training loss: 4.151	Validation loss: 4.131
#
# EPOCH 119:	Training loss: 4.148	Validation loss: 4.129
#
# EPOCH 120:	Training loss: 4.145	Validation loss: 4.126
#
# EPOCH 121:	Training loss: 4.142	Validation loss: 4.123
#
# EPOCH 122:	Training loss: 4.140	Validation loss: 4.120
#
# EPOCH 123:	Training loss: 4.137	Validation loss: 4.117
#
# EPOCH 124:	Training loss: 4.134	Validation loss: 4.115
#
# EPOCH 125:	Training loss: 4.132	Validation loss: 4.112
#
# EPOCH 126:	Training loss: 4.129	Validation loss: 4.109
#
# EPOCH 127:	Training loss: 4.126	Validation loss: 4.107
#
# EPOCH 128:	Training loss: 4.124	Validation loss: 4.104
#
# EPOCH 129:	Training loss: 4.121	Validation loss: 4.101
#
# EPOCH 130:	Training loss: 4.119	Validation loss: 4.099
#
# EPOCH 131:	Training loss: 4.116	Validation loss: 4.096
#
# EPOCH 132:	Training loss: 4.114	Validation loss: 4.094
#
# EPOCH 133:	Training loss: 4.111	Validation loss: 4.091
#
# EPOCH 134:	Training loss: 4.109	Validation loss: 4.089
#
# EPOCH 135:	Training loss: 4.107	Validation loss: 4.087
#
# EPOCH 136:	Training loss: 4.104	Validation loss: 4.084
#
# EPOCH 137:	Training loss: 4.102	Validation loss: 4.082
#
# EPOCH 138:	Training loss: 4.100	Validation loss: 4.080
#
# EPOCH 139:	Training loss: 4.097	Validation loss: 4.077
#
# EPOCH 140:	Training loss: 4.095	Validation loss: 4.075
#
# EPOCH 141:	Training loss: 4.093	Validation loss: 4.073
#
# EPOCH 142:	Training loss: 4.091	Validation loss: 4.071
#
# EPOCH 143:	Training loss: 4.089	Validation loss: 4.068
#
# EPOCH 144:	Training loss: 4.086	Validation loss: 4.066
#
# EPOCH 145:	Training loss: 4.084	Validation loss: 4.064
#
# EPOCH 146:	Training loss: 4.082	Validation loss: 4.062
#
# EPOCH 147:	Training loss: 4.080	Validation loss: 4.060
#
# EPOCH 148:	Training loss: 4.078	Validation loss: 4.058
#
# EPOCH 149:	Training loss: 4.076	Validation loss: 4.056
#
# EPOCH 150:	Training loss: 4.074	Validation loss: 4.054
#
# EPOCH 151:	Training loss: 4.072	Validation loss: 4.052
#
# EPOCH 152:	Training loss: 4.070	Validation loss: 4.050
#
# EPOCH 153:	Training loss: 4.068	Validation loss: 4.048
#
# EPOCH 154:	Training loss: 4.066	Validation loss: 4.046
#
# EPOCH 155:	Training loss: 4.064	Validation loss: 4.044
#
# EPOCH 156:	Training loss: 4.062	Validation loss: 4.042
#
# EPOCH 157:	Training loss: 4.061	Validation loss: 4.040
#
# EPOCH 158:	Training loss: 4.059	Validation loss: 4.038
#
# EPOCH 159:	Training loss: 4.057	Validation loss: 4.036
#
# EPOCH 160:	Training loss: 4.055	Validation loss: 4.034
#
# EPOCH 161:	Training loss: 4.053	Validation loss: 4.033
#
# EPOCH 162:	Training loss: 4.051	Validation loss: 4.031
#
# EPOCH 163:	Training loss: 4.050	Validation loss: 4.029
#
# EPOCH 164:	Training loss: 4.048	Validation loss: 4.027
#
# EPOCH 165:	Training loss: 4.046	Validation loss: 4.026
#
# EPOCH 166:	Training loss: 4.045	Validation loss: 4.024
#
# EPOCH 167:	Training loss: 4.043	Validation loss: 4.022
#
# EPOCH 168:	Training loss: 4.041	Validation loss: 4.020
#
# EPOCH 169:	Training loss: 4.040	Validation loss: 4.019
#
# EPOCH 170:	Training loss: 4.038	Validation loss: 4.017
#
# EPOCH 171:	Training loss: 4.036	Validation loss: 4.015
#
# EPOCH 172:	Training loss: 4.035	Validation loss: 4.014
#
# EPOCH 173:	Training loss: 4.033	Validation loss: 4.012
#
# EPOCH 174:	Training loss: 4.032	Validation loss: 4.011
#
# EPOCH 175:	Training loss: 4.030	Validation loss: 4.009
#
# EPOCH 176:	Training loss: 4.028	Validation loss: 4.007
#
# EPOCH 177:	Training loss: 4.027	Validation loss: 4.006
#
# EPOCH 178:	Training loss: 4.025	Validation loss: 4.004
#
# EPOCH 179:	Training loss: 4.024	Validation loss: 4.003
#
# EPOCH 180:	Training loss: 4.022	Validation loss: 4.001
#
# EPOCH 181:	Training loss: 4.021	Validation loss: 4.000
#
# EPOCH 182:	Training loss: 4.019	Validation loss: 3.998
#
# EPOCH 183:	Training loss: 4.018	Validation loss: 3.997
#
# EPOCH 184:	Training loss: 4.017	Validation loss: 3.995
#
# EPOCH 185:	Training loss: 4.015	Validation loss: 3.994
#
# EPOCH 186:	Training loss: 4.014	Validation loss: 3.993
#
# EPOCH 187:	Training loss: 4.012	Validation loss: 3.991
#
# EPOCH 188:	Training loss: 4.011	Validation loss: 3.990
#
# EPOCH 189:	Training loss: 4.010	Validation loss: 3.988
#
# EPOCH 190:	Training loss: 4.008	Validation loss: 3.987
#
# EPOCH 191:	Training loss: 4.007	Validation loss: 3.986
#
# EPOCH 192:	Training loss: 4.006	Validation loss: 3.984
#
# EPOCH 193:	Training loss: 4.004	Validation loss: 3.983
#
# EPOCH 194:	Training loss: 4.003	Validation loss: 3.982
#
# EPOCH 195:	Training loss: 4.002	Validation loss: 3.980
#
# EPOCH 196:	Training loss: 4.000	Validation loss: 3.979
#
# EPOCH 197:	Training loss: 3.999	Validation loss: 3.978
#
# EPOCH 198:	Training loss: 3.998	Validation loss: 3.976
#
# EPOCH 199:	Training loss: 3.997	Validation loss: 3.975
#
# EPOCH 200:	Training loss: 3.995	Validation loss: 3.974

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Loss')
ax[1, 0].set_title('Train Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Loss')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_accs = compute_accuracy(X_val, y_val, theta)
test_set_accs = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set:')
print(f'Accuracy on validation set: {val_set_accs}')
print(f'Accuracy on test set: {test_set_accs}')
# Out:
# Evaluation on validation and test set:
# Accuracy on validation set: 0.8232323232323232
# Accuracy on test set: 0.8446969696969697
